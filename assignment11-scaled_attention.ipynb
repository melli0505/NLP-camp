# %% [markdown]
# # Install

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 14.8MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # Evn

# %%
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as KK

from tqdm.notebook import tqdm

# %%
# random seed initialize
random_seed = 1234
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# !nvidia-smi
# Out:
# Mon Feb  8 11:41:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data dir
data_dir = '/content/drive/MyDrive/NLP_data'
os.listdir(data_dir)
# Out:
# ['ko_32000.model',
#  'ko_32000.vocab',
#  'kowiki',
#  '.ipynb_checkpoints',
#  'nsmc',
#  'quora',
#  'songys']

# %%
# songys chatbot dir
songys_dir = os.path.join(data_dir, 'songys')
if not os.path.exists(songys_dir):
    os.makedirs(songys_dir)
os.listdir(songys_dir)
# Out:
# ['ChatbotData.csv', 'lstm.csv', 'lstm.hdf5', 'lstm_dot.csv', 'lstm_dot.hdf5']

# %% [markdown]
# # Attention

# %%
def get_pad_mask(tokens, i_pad=0):
    """
    pad mask 계산하는 함수
    :param tokens: tokens (bs, n_seq)
    :param i_pad: id of pad
    :return mask: pad mask (pad: 1, other: 0)
    """
    # 0인 부분 확인
    mask = tf.math.equal(tokens, i_pad)
    # boolean -> float 32
    mask = tf.cast(mask, tf.float32)
    # expand dimension for n_seq
    mask = tf.expand_dims(mask, axis=1)
    return mask

# %%
class ScaleDotProductAttention(tf.keras.layers.Layer):
    """
    Scale Dot Product Attention Class
    """
    def __init__(self, name="scale_dot_product_attention"):
        """
        생성자
        :param name: layer name
        """
        super().__init__(name=name)

    def call(self, inputs):
        """
        layer 실행
        :param inputs: Q, K, V, attn_mask tuple
        :return attn_out: attention 실행 결과
        """
        Q, K, V, attn_mask = inputs
        # matmul Q, K (transpose_b=True)
        attn_score = tf.matmul(Q, K, transpose_b=True)
        # get scale = d_model ** 0.5
        scale = tf.math.sqrt(tf.cast(tf.shape(K)[-1], tf.float32))
        # divide by scale
        attn_scale = tf.math.divide(attn_score, scale)
        # do mask (subtract 1e-9 for masked value)
        attn_scale -= 1.e9 * attn_mask
        # calculate attention prob
        attn_prob = tf.nn.softmax(attn_scale, axis=-1)
        # weighted sum of V
        attn_out = tf.matmul(attn_prob, V)
        return attn_out

# %% [markdown]
# # Vocabulary & config

# %%
# vocab loading
vocab = spm.SentencePieceProcessor()
vocab.load(os.path.join(data_dir, 'ko_32000.model'))
# Out:
# True

# %%
n_vocab = len(vocab)  # number of vocabulary
n_enc_seq = 32  # number of sequence 1
n_dec_seq = 40  # number of sequence 2
d_model = 256  # dimension of model

# %% [markdown]
# # 모델링

# %%
def build_model(n_vocab, d_model, n_enc_seq, n_dec_seq):
    """
    문장 유사도 비교 모델
    :param n_vocab: vocabulary 단어 수
    :param d_model: 단어를 의미하는 벡터의 차원 수
    :param n_enc_seq: encoder 문장 길이 (단어 수)
    :param n_dec_seq: decoder 문장 길이 (단어 수)
    """
    inputs_enc = tf.keras.layers.Input((n_enc_seq,))  # (bs, n_enc_seq)
    inputs_dec = tf.keras.layers.Input((n_dec_seq,))  # (bs, n_dec_seq)
    # pad mask 생성
    ###############################################
    pad_mask = get_pad_mask(inputs_enc)
    ###############################################
    # 입력 단어를 vector로 변환
    embedding = tf.keras.layers.Embedding(n_vocab, d_model)
    hidden_enc = embedding(inputs_enc)  # (bs, n_enc_seq, d_model)
    hidden_dec = embedding(inputs_dec)  # (bs, n_dec_seq, d_model)
    # encoder LSTM
    fw_cell = tf.keras.layers.LSTM(units=d_model, return_sequences=True, return_state=True)
    bw_cell = tf.keras.layers.LSTM(units=d_model, go_backwards=True, return_sequences=True, return_state=True)
    lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)
    hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, n_enc_seq, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)
    # concat hidden & cell
    s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
    s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)
    # decoder LSTM
    lstm_dec = tf.keras.layers.LSTM(units=d_model * 2, return_sequences=True)
    hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)
    # ScaleDotProductAttention 실행
    ##############################################
    attention = ScaleDotProductAttention()
    attn_out = attention((hidden_dec, hidden_enc, hidden_enc, pad_mask))
    ##############################################
    # concat output
    dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
    # 다음단어 예측
    dense_out = tf.keras.layers.Dense(units=n_vocab, activation=tf.nn.softmax)
    outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
    # 학습할 모델 선언
    model = tf.keras.Model(inputs=(inputs_enc, inputs_dec), outputs=outputs)
    return model

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %% [markdown]
# # Loss & Acc

# %%
def lm_loss(y_true, y_pred):
    """
    pad 부분을 제외하고 loss를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 loss 값
    """
    # loss = sparse_entropy = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)(y_true, y_pred)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    loss *= mask
    return loss

# %%
def lm_acc(y_true, y_pred):
    """
    pad 부분을 제외하고 accuracy를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 accuracy 값
    """
    y_true = tf.cast(y_true, tf.float32)
    # print(y_true)
    y_pred_class = tf.cast(tf.argmax(y_pred, axis=-1), tf.float32)
    # print(y_pred_class)
    matches = tf.cast(tf.equal(y_true, y_pred_class), tf.float32)
    # print(matches)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    matches *= mask
    # print(matches)
    # accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(tf.ones_like(matches)), 1)
    accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(mask), 1)
    return accuracy

# %% [markdown]
# # All Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
print(len(df_train))
df_train = df_train.dropna()
print(len(df_train))
df_train
# Out:
# 11823
# 11823
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        Q = row['Q']
        A = row['A']

        tokens_q = vocab.encode_as_pieces(Q)
        tokens_a = vocab.encode_as_pieces(A)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11823.0), HTML(value='')))
# (array([[   89,    56,    10, ...,     0,     0,     0],
#         [   35,    47,  1004, ...,     0,     0,     0],
#         [   38,   819,   362, ...,     0,     0,     0],
#         ...,
#         [ 2886,  9525, 21930, ...,     0,     0,     0],
#         [10736,  8256,  1172, ...,     0,     0,     0],
#         [26128,    70,  1381, ...,     0,     0,     0]], dtype=int32),
#  array([[    2,  2261,    19, ...,     0,     0,     0],
#         [    2,  4594,    61, ...,     0,     0,     0],
#         [    2,  2350,    18, ...,     0,     0,     0],
#         ...,
#         [    2,  1522,     1, ...,     0,     0,     0],
#         [    2,   441, 10316, ...,     0,     0,     0],
#         [    2, 16665,    90, ...,     0,     0,     0]], dtype=int32),
#  array([[ 2261,    19,   375, ...,     0,     0,     0],
#         [ 4594,    61,   929, ...,     0,     0,     0],
#         [ 2350,    18,  9001, ...,     0,     0,     0],
#         ...,
#         [ 1522,     1, 12273, ...,     0,     0,     0],
#         [  441, 10316,   515, ...,     0,     0,     0],
#         [16665,    90,  1381, ...,     0,     0,     0]], dtype=int32))

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=5)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_scale_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=100,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 48s 800ms/step - loss: 1.8905 - lm_acc: 0.1167
#
# Epoch 00001: lm_acc improved from -inf to 0.12079, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 2/100
# 47/47 [==============================] - 40s 847ms/step - loss: 1.2889 - lm_acc: 0.1434
#
# Epoch 00002: lm_acc improved from 0.12079 to 0.16470, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 3/100
# 47/47 [==============================] - 43s 905ms/step - loss: 1.1716 - lm_acc: 0.2541
#
# Epoch 00003: lm_acc improved from 0.16470 to 0.26959, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 4/100
# 47/47 [==============================] - 41s 878ms/step - loss: 1.0885 - lm_acc: 0.2889
#
# Epoch 00004: lm_acc improved from 0.26959 to 0.29530, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 5/100
# 47/47 [==============================] - 42s 901ms/step - loss: 1.0317 - lm_acc: 0.3198
#
# Epoch 00005: lm_acc improved from 0.29530 to 0.32962, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 6/100
# 47/47 [==============================] - 42s 894ms/step - loss: 0.9728 - lm_acc: 0.3517
#
# Epoch 00006: lm_acc improved from 0.32962 to 0.35615, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 7/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.9241 - lm_acc: 0.3722
#
# Epoch 00007: lm_acc improved from 0.35615 to 0.37886, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 8/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.8721 - lm_acc: 0.3931
#
# Epoch 00008: lm_acc improved from 0.37886 to 0.39689, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 9/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.8286 - lm_acc: 0.4086
#
# Epoch 00009: lm_acc improved from 0.39689 to 0.41013, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 10/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.7923 - lm_acc: 0.4218
#
# Epoch 00010: lm_acc improved from 0.41013 to 0.42251, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 11/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.7550 - lm_acc: 0.4362
#
# Epoch 00011: lm_acc improved from 0.42251 to 0.43541, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 12/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.7182 - lm_acc: 0.4494
#
# Epoch 00012: lm_acc improved from 0.43541 to 0.44968, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 13/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.6846 - lm_acc: 0.4634
#
# Epoch 00013: lm_acc improved from 0.44968 to 0.46332, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 14/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.6544 - lm_acc: 0.4792
#
# Epoch 00014: lm_acc improved from 0.46332 to 0.47975, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 15/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.6177 - lm_acc: 0.4990
#
# Epoch 00015: lm_acc improved from 0.47975 to 0.49902, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 16/100
# 47/47 [==============================] - 42s 901ms/step - loss: 0.5787 - lm_acc: 0.5207
#
# Epoch 00016: lm_acc improved from 0.49902 to 0.51812, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 17/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.5509 - lm_acc: 0.5395
#
# Epoch 00017: lm_acc improved from 0.51812 to 0.53775, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 18/100
# 47/47 [==============================] - 42s 902ms/step - loss: 0.5207 - lm_acc: 0.5603
#
# Epoch 00018: lm_acc improved from 0.53775 to 0.55711, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 19/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.4932 - lm_acc: 0.5818
#
# Epoch 00019: lm_acc improved from 0.55711 to 0.57798, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 20/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.4604 - lm_acc: 0.6031
#
# Epoch 00020: lm_acc improved from 0.57798 to 0.59833, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 21/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.4356 - lm_acc: 0.6224
#
# Epoch 00021: lm_acc improved from 0.59833 to 0.61770, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 22/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.4128 - lm_acc: 0.6390
#
# Epoch 00022: lm_acc improved from 0.61770 to 0.63460, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 23/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.3925 - lm_acc: 0.6550
#
# Epoch 00023: lm_acc improved from 0.63460 to 0.65361, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 24/100
# 47/47 [==============================] - 42s 902ms/step - loss: 0.3668 - lm_acc: 0.6757
#
# Epoch 00024: lm_acc improved from 0.65361 to 0.67104, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 25/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.3513 - lm_acc: 0.6892
#
# Epoch 00025: lm_acc improved from 0.67104 to 0.68723, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 26/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.3303 - lm_acc: 0.7072
#
# Epoch 00026: lm_acc improved from 0.68723 to 0.70276, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 27/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.3103 - lm_acc: 0.7259
#
# Epoch 00027: lm_acc improved from 0.70276 to 0.71863, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 28/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.2957 - lm_acc: 0.7354
#
# Epoch 00028: lm_acc improved from 0.71863 to 0.73293, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 29/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.2808 - lm_acc: 0.7515
#
# Epoch 00029: lm_acc improved from 0.73293 to 0.74841, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 30/100
# 47/47 [==============================] - 42s 901ms/step - loss: 0.2627 - lm_acc: 0.7675
#
# Epoch 00030: lm_acc improved from 0.74841 to 0.76411, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 31/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.2504 - lm_acc: 0.7791
#
# Epoch 00031: lm_acc improved from 0.76411 to 0.77651, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 32/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.2332 - lm_acc: 0.7947
#
# Epoch 00032: lm_acc improved from 0.77651 to 0.79053, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 33/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.2235 - lm_acc: 0.8040
#
# Epoch 00033: lm_acc improved from 0.79053 to 0.80112, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 34/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.2114 - lm_acc: 0.8153
#
# Epoch 00034: lm_acc improved from 0.80112 to 0.81289, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 35/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.1974 - lm_acc: 0.8290
#
# Epoch 00035: lm_acc improved from 0.81289 to 0.82635, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 36/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.1858 - lm_acc: 0.8411
#
# Epoch 00036: lm_acc improved from 0.82635 to 0.83707, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 37/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.1729 - lm_acc: 0.8526
#
# Epoch 00037: lm_acc improved from 0.83707 to 0.84998, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 38/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.1635 - lm_acc: 0.8640
#
# Epoch 00038: lm_acc improved from 0.84998 to 0.85931, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 39/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.1547 - lm_acc: 0.8716
#
# Epoch 00039: lm_acc improved from 0.85931 to 0.86789, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 40/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.1449 - lm_acc: 0.8823
#
# Epoch 00040: lm_acc improved from 0.86789 to 0.87780, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 41/100
# 47/47 [==============================] - 42s 894ms/step - loss: 0.1356 - lm_acc: 0.8922
#
# Epoch 00041: lm_acc improved from 0.87780 to 0.88811, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 42/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.1284 - lm_acc: 0.8994
#
# Epoch 00042: lm_acc improved from 0.88811 to 0.89589, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 43/100
# 47/47 [==============================] - 42s 896ms/step - loss: 0.1204 - lm_acc: 0.9071
#
# Epoch 00043: lm_acc improved from 0.89589 to 0.90453, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 44/100
# 47/47 [==============================] - 42s 896ms/step - loss: 0.1112 - lm_acc: 0.9167
#
# Epoch 00044: lm_acc improved from 0.90453 to 0.91268, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 45/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.1067 - lm_acc: 0.9216
#
# Epoch 00045: lm_acc improved from 0.91268 to 0.91705, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 46/100
# 47/47 [==============================] - 42s 893ms/step - loss: 0.0991 - lm_acc: 0.9284
#
# Epoch 00046: lm_acc improved from 0.91705 to 0.92645, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 47/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.0935 - lm_acc: 0.9343
#
# Epoch 00047: lm_acc improved from 0.92645 to 0.92943, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 48/100
# 47/47 [==============================] - 42s 894ms/step - loss: 0.0955 - lm_acc: 0.9298
#
# Epoch 00048: lm_acc improved from 0.92943 to 0.92999, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 49/100
# 47/47 [==============================] - 42s 903ms/step - loss: 0.0831 - lm_acc: 0.9436
#
# Epoch 00049: lm_acc improved from 0.92999 to 0.94214, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 50/100
# 47/47 [==============================] - 42s 896ms/step - loss: 0.0779 - lm_acc: 0.9494
#
# Epoch 00050: lm_acc improved from 0.94214 to 0.94631, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 51/100
# 47/47 [==============================] - 42s 896ms/step - loss: 0.0740 - lm_acc: 0.9534
#
# Epoch 00051: lm_acc improved from 0.94631 to 0.94926, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 52/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.0719 - lm_acc: 0.9542
#
# Epoch 00052: lm_acc improved from 0.94926 to 0.95353, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 53/100
# 47/47 [==============================] - 42s 893ms/step - loss: 0.0643 - lm_acc: 0.9614
#
# Epoch 00053: lm_acc improved from 0.95353 to 0.96089, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 54/100
# 47/47 [==============================] - 42s 894ms/step - loss: 0.0578 - lm_acc: 0.9673
#
# Epoch 00054: lm_acc improved from 0.96089 to 0.96534, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 55/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.0557 - lm_acc: 0.9698
#
# Epoch 00055: lm_acc improved from 0.96534 to 0.96776, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 56/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.0517 - lm_acc: 0.9733
#
# Epoch 00056: lm_acc improved from 0.96776 to 0.97151, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 57/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.0476 - lm_acc: 0.9756
#
# Epoch 00057: lm_acc improved from 0.97151 to 0.97428, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 58/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.0457 - lm_acc: 0.9777
#
# Epoch 00058: lm_acc improved from 0.97428 to 0.97779, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 59/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.0411 - lm_acc: 0.9818
#
# Epoch 00059: lm_acc improved from 0.97779 to 0.98074, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 60/100
# 47/47 [==============================] - 42s 894ms/step - loss: 0.0399 - lm_acc: 0.9826
#
# Epoch 00060: lm_acc did not improve from 0.98074
# Epoch 61/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.0408 - lm_acc: 0.9814
#
# Epoch 00061: lm_acc improved from 0.98074 to 0.98095, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 62/100
# 47/47 [==============================] - 42s 901ms/step - loss: 0.0365 - lm_acc: 0.9848
#
# Epoch 00062: lm_acc improved from 0.98095 to 0.98415, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 63/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.0325 - lm_acc: 0.9876
#
# Epoch 00063: lm_acc improved from 0.98415 to 0.98710, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 64/100
# 47/47 [==============================] - 42s 896ms/step - loss: 0.0303 - lm_acc: 0.9894
#
# Epoch 00064: lm_acc improved from 0.98710 to 0.98882, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 65/100
# 47/47 [==============================] - 42s 898ms/step - loss: 0.0275 - lm_acc: 0.9913
#
# Epoch 00065: lm_acc improved from 0.98882 to 0.98994, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 66/100
# 47/47 [==============================] - 42s 897ms/step - loss: 0.0261 - lm_acc: 0.9914
#
# Epoch 00066: lm_acc improved from 0.98994 to 0.99105, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 67/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.0247 - lm_acc: 0.9926
#
# Epoch 00067: lm_acc improved from 0.99105 to 0.99222, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 68/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.0223 - lm_acc: 0.9939
#
# Epoch 00068: lm_acc improved from 0.99222 to 0.99342, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 69/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.0206 - lm_acc: 0.9952
#
# Epoch 00069: lm_acc improved from 0.99342 to 0.99417, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 70/100
# 47/47 [==============================] - 42s 900ms/step - loss: 0.0198 - lm_acc: 0.9952
#
# Epoch 00070: lm_acc improved from 0.99417 to 0.99496, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 71/100
# 47/47 [==============================] - 42s 895ms/step - loss: 0.0179 - lm_acc: 0.9964
#
# Epoch 00071: lm_acc improved from 0.99496 to 0.99562, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 72/100
# 47/47 [==============================] - 42s 899ms/step - loss: 0.0171 - lm_acc: 0.9962
#
# Epoch 00072: lm_acc improved from 0.99562 to 0.99588, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 73/100
# 47/47 [==============================] - 42s 892ms/step - loss: 0.0162 - lm_acc: 0.9966
#
# Epoch 00073: lm_acc improved from 0.99588 to 0.99638, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 74/100
# 47/47 [==============================] - 42s 886ms/step - loss: 0.0149 - lm_acc: 0.9969
#
# Epoch 00074: lm_acc improved from 0.99638 to 0.99678, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 75/100
# 47/47 [==============================] - 42s 888ms/step - loss: 0.0139 - lm_acc: 0.9973
#
# Epoch 00075: lm_acc improved from 0.99678 to 0.99714, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 76/100
# 47/47 [==============================] - 42s 883ms/step - loss: 0.0135 - lm_acc: 0.9974
#
# Epoch 00076: lm_acc did not improve from 0.99714
# Epoch 77/100
# 47/47 [==============================] - 42s 887ms/step - loss: 0.0138 - lm_acc: 0.9974
#
# Epoch 00077: lm_acc did not improve from 0.99714
# Epoch 78/100
# 47/47 [==============================] - 42s 891ms/step - loss: 0.0130 - lm_acc: 0.9975
#
# Epoch 00078: lm_acc improved from 0.99714 to 0.99760, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 79/100
# 47/47 [==============================] - 42s 883ms/step - loss: 0.0126 - lm_acc: 0.9975
#
# Epoch 00079: lm_acc did not improve from 0.99760
# Epoch 80/100
# 47/47 [==============================] - 42s 886ms/step - loss: 0.0135 - lm_acc: 0.9972
#
# Epoch 00080: lm_acc did not improve from 0.99760
# Epoch 81/100
# 47/47 [==============================] - 42s 886ms/step - loss: 0.0129 - lm_acc: 0.9970
#
# Epoch 00081: lm_acc did not improve from 0.99760
# Epoch 82/100
# 47/47 [==============================] - 42s 887ms/step - loss: 0.0112 - lm_acc: 0.9983
#
# Epoch 00082: lm_acc improved from 0.99760 to 0.99763, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 83/100
# 47/47 [==============================] - 42s 884ms/step - loss: 0.0109 - lm_acc: 0.9982
#
# Epoch 00083: lm_acc improved from 0.99763 to 0.99774, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 84/100
# 47/47 [==============================] - 42s 883ms/step - loss: 0.0097 - lm_acc: 0.9984
#
# Epoch 00084: lm_acc improved from 0.99774 to 0.99805, saving model to /content/drive/MyDrive/NLP_data/songys/lstm_scale_dot.hdf5
# Epoch 85/100
# 47/47 [==============================] - 41s 881ms/step - loss: 0.0089 - lm_acc: 0.9984
#
# Epoch 00085: lm_acc did not improve from 0.99805
# Epoch 86/100
# 47/47 [==============================] - 41s 879ms/step - loss: 0.0173 - lm_acc: 0.9919
#
# Epoch 00086: lm_acc did not improve from 0.99805
# Epoch 87/100
# 47/47 [==============================] - 41s 881ms/step - loss: 0.0182 - lm_acc: 0.9924
#
# Epoch 00087: lm_acc did not improve from 0.99805
# Epoch 88/100
# 47/47 [==============================] - 42s 888ms/step - loss: 0.0265 - lm_acc: 0.9837
#
# Epoch 00088: lm_acc did not improve from 0.99805
# Epoch 89/100
# 47/47 [==============================] - 42s 891ms/step - loss: 0.0155 - lm_acc: 0.9941
#
# Epoch 00089: lm_acc did not improve from 0.99805

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'))

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')
# Out:
# 질문 > 안녕?
# 답변 > 안녕하세요.
# 질문 > 오늘 날씨 어때?
# 답변 > 오늘은 예능이요.
# 질문 > 재밌는 거 있어?
# 답변 > 잼 있는 거는 딸기잼에게 물어봐요.
# 질문 > 선넘네
# 답변 > 예쁠 수도 없죠.
# 질문 > 게임하고 싶다
# 답변 > 게임하세요!
# 질문 > 시간이 많았으면 좋겠어
# 답변 > 쉬운 일은 아니에요.
# 질문 > 맞아
# 답변 > 그렇지 않은게요.
# 질문 > 아니야
# 답변 > 저도 몰랐어요.
# 질문 > 풍차
# 답변 > 저도요.
# 질문 > 무슨 향기가 좋아?
# 답변 > 감정에 확신이 있다면 연락해보세요.
# 질문 > 뭐해?
# 답변 > 독서와 음악감상이라고 하고 싶지만 아무 것도 안 했어요.
# 질문 > 나랑 똑같네
# 답변 > 당신의 인생을 찾아보세요.
# 질문 > 인공지능?
# 답변 > 기다리고 있었어요.
# 질문 > 이름이 뭐야?
# 답변 > 위로봇이요.
# 질문 > 몇 살이야?
# 답변 > 이제 취업, 좋은 곳에서 살 거예요.
# 질문 > 어디 살아?
# 답변 > 저는 주당이에요.
# 질문 >
